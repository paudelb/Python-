# %%
import numpy as np 
import math

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
X = np.linspace(-2,2, 100) 
A = np.tanh(X) 
B = np.tanh(0.5*X)
C = np.tanh(2*X)
D = X
E = 0
plt.plot(X, B,'b', X, C,'g',X, D,'y',label='go') 
plt.title("tanh(L)") 
plt.xlabel("X") 
plt.ylabel("Y") 
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
X = np.linspace(-2,2, 100) 
A = np.tanh(X) 
B = np.tanh(0.5*X)
C = np.tanh(2*X)
D = X
E = 0
ax= plt.axes()
l1 = ax.plot(X, B,'b',label='l1')
l2 = ax.plot(X, C,'g',label='l2')
l3 = ax.plot(X, D,'y',label='l3')
l4 = ax.plot(X,X*0,'k')
l5 = ax.plot(0*X,X,'k')
plt.title("tanh(L)") 
plt.xlabel("X") 
plt.ylabel("Y") 
plt.show()
